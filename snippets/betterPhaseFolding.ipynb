# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import lightkurve as lk

# %%
TIC = 'TIC 55525572'
sector_data = lk.search_lightcurve(TIC, author = 'SPOC')
sector_data
# Out:
# SearchResult containing 42 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 04 2018   SPOC     120    55525572      0.0
#   1 TESS Sector 05 2018   SPOC     120    55525572      0.0
#   2 TESS Sector 06 2018   SPOC     120    55525572      0.0
#   3 TESS Sector 08 2019   SPOC     120    55525572      0.0
#   4 TESS Sector 09 2019   SPOC     120    55525572      0.0
#   5 TESS Sector 10 2019   SPOC     120    55525572      0.0
#   6 TESS Sector 11 2019   SPOC     120    55525572      0.0
#   7 TESS Sector 12 2019   SPOC     120    55525572      0.0
#   8 TESS Sector 13 2019   SPOC     120    55525572      0.0
#   9 TESS Sector 27 2020   SPOC      20    55525572      0.0
# ...            ...  ...    ...     ...         ...      ...
#  32 TESS Sector 66 2023   SPOC      20    55525572      0.0
#  33 TESS Sector 68 2023   SPOC     120    55525572      0.0
#  34 TESS Sector 67 2023   SPOC     120    55525572      0.0
#  35 TESS Sector 64 2023   SPOC     120    55525572      0.0
#  36 TESS Sector 65 2023   SPOC     120    55525572      0.0
#  37 TESS Sector 63 2023   SPOC     120    55525572      0.0
#  38 TESS Sector 62 2023   SPOC     120    55525572      0.0
#  39 TESS Sector 61 2023   SPOC     120    55525572      0.0
#  40 TESS Sector 66 2023   SPOC     120    55525572      0.0
#  41 TESS Sector 69 2023   SPOC     120    55525572      0.0
# Length = 42 rows

# %%
# %matplotlib inline
select_sector = sector_data[0:4]
select_sector
# Out:
# SearchResult containing 4 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 04 2018   SPOC     120    55525572      0.0
#   1 TESS Sector 05 2018   SPOC     120    55525572      0.0
#   2 TESS Sector 06 2018   SPOC     120    55525572      0.0
#   3 TESS Sector 08 2019   SPOC     120    55525572      0.0

# %%
lc_collection = select_sector.download_all()
lc_collection
# Out:
# LightCurveCollection of 4 objects:
#     0: <TessLightCurve LABEL="TIC 55525572" SECTOR=4 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     1: <TessLightCurve LABEL="TIC 55525572" SECTOR=5 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     2: <TessLightCurve LABEL="TIC 55525572" SECTOR=6 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     3: <TessLightCurve LABEL="TIC 55525572" SECTOR=8 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>

# %%
# %matplotlib inline
lc = select_sector.download_all()
lc.plot(linewidth = 0, marker = '.', color = 'midnightblue', alpha = 0.5)
# Out:
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
lc_collection_stitched = lc_collection.stitch()

# %%
lc_collection_stitched.plot(linewidth = 0, marker = '.', color = 'midnightblue', alpha = 0.5)
# Out:
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %%
bin_time = 15/24/60
lc_collection_binned = lc_collection_stitched.bin(bin_time)
lc_collection_binned.plot(linewidth = 0, marker = '.', color = 'midnightblue', alpha = 0.5)
# Out:
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %%
fig, ax = plt.subplots(figsize = (10, 5)) # Figure & axis
lc_collection_stitched.plot(ax = ax, linewidth = 0, marker = '.', color = 'midnightblue', alpha = 0.5)
lc_collection_binned.plot(ax = ax, linewidth = 0, marker = 'o', color = 'red', alpha = 0.5)
# Out:
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>
