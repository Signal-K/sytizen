# %% [markdown]
# # Lightcurve Manipulation

# %%
# %matplotlib notebook

import sys
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install lightkurve
# !{sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install astropy

import matplotlib.pyplot as plt
import lightkurve as lk
import astropy
import numpy as np
# Out:
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.10/site-packages (1.23.3)
# Collecting lightkurve
#   Using cached lightkurve-2.3.0-py3-none-any.whl (259 kB)
# Collecting tqdm>=4.25.0
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# Collecting memoization>=0.3.1
#   Using cached memoization-0.4.0.tar.gz (41 kB)
#   Preparing metadata (setup.py) ... done
# Collecting uncertainties>=3.1.4
#   Using cached uncertainties-3.1.7-py2.py3-none-any.whl (98 kB)
# Requirement already satisfied: matplotlib>=3.1 in /home/codespace/.local/lib/python3.10/site-packages (from lightkurve) (3.6.0)
# Requirement already satisfied: requests>=2.22.0 in /home/codespace/.local/lib/python3.10/site-packages (from lightkurve) (2.28.1)
# Collecting astroquery>=0.3.10
#   Using cached astroquery-0.4.6-py3-none-any.whl (4.5 MB)
# Collecting beautifulsoup4>=4.6.0
#   Using cached beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
# Requirement already satisfied: numpy>=1.18 in /home/codespace/.local/lib/python3.10/site-packages (from lightkurve) (1.23.3)
# Collecting oktopus>=0.1.2
#   Using cached oktopus-0.1.2.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.1.4 in /home/codespace/.local/lib/python3.10/site-packages (from lightkurve) (1.5.0)
# Collecting patsy>=0.5.0
#   Using cached patsy-0.5.2-py2.py3-none-any.whl (233 kB)
# Requirement already satisfied: scikit-learn>=0.24.0 in /home/codespace/.local/lib/python3.10/site-packages (from lightkurve) (1.1.2)
# Requirement already satisfied: scipy>=1.7 in /home/codespace/.local/lib/python3.10/site-packages (from lightkurve) (1.9.1)
# Requirement already satisfied: urllib3>=1.23 in /home/codespace/.local/lib/python3.10/site-packages (from lightkurve) (1.26.12)
# Collecting fbpca>=1.0
#   Using cached fbpca-1.0.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting astropy>=5.0
#   Downloading astropy-5.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 48.8 MB/s eta 0:00:0000:010:01
# Collecting bokeh>=1.1
#   Using cached bokeh-2.4.3-py3-none-any.whl (18.5 MB)
# Requirement already satisfied: packaging>=19.0 in /home/codespace/.local/lib/python3.10/site-packages (from astropy>=5.0->lightkurve) (21.3)
# Collecting PyYAML>=3.13
#   Downloading PyYAML-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (682 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 682.2/682.2 kB 20.9 MB/s eta 0:00:00
# Collecting pyerfa>=2.0
#   Downloading pyerfa-2.0.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (743 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 743.2/743.2 kB 20.3 MB/s eta 0:00:0000:01
# Collecting html5lib>=0.999
#   Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Collecting keyring>=4.0
#   Using cached keyring-23.9.3-py3-none-any.whl (35 kB)
# Collecting pyvo>=1.1
#   Using cached pyvo-1.4-py3-none-any.whl (885 kB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Requirement already satisfied: typing-extensions>=3.10.0 in /home/codespace/.local/lib/python3.10/site-packages (from bokeh>=1.1->lightkurve) (4.3.0)
# Requirement already satisfied: tornado>=5.1 in /home/codespace/.local/lib/python3.10/site-packages (from bokeh>=1.1->lightkurve) (6.2)
# Collecting Jinja2>=2.9
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Requirement already satisfied: pillow>=7.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from bokeh>=1.1->lightkurve) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.1->lightkurve) (4.37.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.1->lightkurve) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.1->lightkurve) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.1->lightkurve) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.1->lightkurve) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.1->lightkurve) (3.0.9)
# Collecting autograd
#   Using cached autograd-1.5-py3-none-any.whl (48 kB)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas>=1.1.4->lightkurve) (2022.2.1)
# Requirement already satisfied: six in /home/codespace/.local/lib/python3.10/site-packages (from patsy>=0.5.0->lightkurve) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.22.0->lightkurve) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.22.0->lightkurve) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests>=2.22.0->lightkurve) (2022.9.14)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from scikit-learn>=0.24.0->lightkurve) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from scikit-learn>=0.24.0->lightkurve) (1.2.0)
# Collecting future
#   Using cached future-0.18.2.tar.gz (829 kB)
#   Preparing metadata (setup.py) ... done
# Collecting webencodings
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from Jinja2>=2.9->bokeh>=1.1->lightkurve) (2.1.1)
# Collecting jaraco.classes
#   Using cached jaraco.classes-3.2.3-py3-none-any.whl (6.0 kB)
# Collecting SecretStorage>=3.2
#   Using cached SecretStorage-3.3.3-py3-none-any.whl (15 kB)
# Collecting jeepney>=0.4.2
#   Using cached jeepney-0.8.0-py3-none-any.whl (48 kB)
# Collecting cryptography>=2.0
#   Using cached cryptography-38.0.1-cp36-abi3-manylinux_2_28_x86_64.whl (4.2 MB)
# Collecting more-itertools
#   Using cached more_itertools-8.14.0-py3-none-any.whl (52 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (441 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 441.8/441.8 kB 15.3 MB/s eta 0:00:00
# Collecting pycparser
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Building wheels for collected packages: fbpca, memoization, oktopus, future
#   Building wheel for fbpca (setup.py) ... done
#   Created wheel for fbpca: filename=fbpca-1.0-py3-none-any.whl size=11373 sha256=26cedbf5ab886aea07e6fda6e23c08bac41a16a426d30ed59a145dc1b02cbf73
#   Stored in directory: /home/codespace/.cache/pip/wheels/3c/ea/60/8d1c9fbbc99492a1775b36a5e29c8c1ef309cc5821bd5a219d
#   Building wheel for memoization (setup.py) ... done
#   Created wheel for memoization: filename=memoization-0.4.0-py3-none-any.whl size=50450 sha256=1ba6baf75f218cc30e52ad58381d45cd9561e509af7212e365832eedd0954f72
#   Stored in directory: /home/codespace/.cache/pip/wheels/3e/b8/c5/b553d5e8b0249bd2859b3b6d7bb2a1849e7b01c6e8b64f6e87
#   Building wheel for oktopus (setup.py) ... done
#   Created wheel for oktopus: filename=oktopus-0.1.2-py3-none-any.whl size=12763 sha256=81b4d12083cf7c00c0744d5960439cc1afef45fc9f0a119868b85bc3b60c6ca3
#   Stored in directory: /home/codespace/.cache/pip/wheels/b6/55/53/8d7c151deab7a11f182e5a69feb906cab95123da7a2438ed9d
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491058 sha256=281f3b5dbb5f042c0810ee8af15427cac1de1923e431c7269dcc3fc29aa820ea
#   Stored in directory: /home/codespace/.cache/pip/wheels/22/73/06/557dc4f4ef68179b9d763930d6eec26b88ed7c389b19588a1c
# Successfully built fbpca memoization oktopus future
# Installing collected packages: webencodings, fbpca, tqdm, soupsieve, PyYAML, pyerfa, pycparser, patsy, more-itertools, memoization, Jinja2, jeepney, html5lib, future, uncertainties, jaraco.classes, cffi, bokeh, beautifulsoup4, autograd, astropy, pyvo, oktopus, cryptography, SecretStorage, keyring, astroquery, lightkurve
# Successfully installed Jinja2-3.1.2 PyYAML-6.0 SecretStorage-3.3.3 astropy-5.1 astroquery-0.4.6 autograd-1.5 beautifulsoup4-4.11.1 bokeh-2.4.3 cffi-1.15.1 cryptography-38.0.1 fbpca-1.0 future-0.18.2 html5lib-1.1 jaraco.classes-3.2.3 jeepney-0.8.0 keyring-23.9.3 lightkurve-2.3.0 memoization-0.4.0 more-itertools-8.14.0 oktopus-0.1.2 patsy-0.5.2 pycparser-2.21 pyerfa-2.0.0.1 pyvo-1.4 soupsieve-2.3.2.post1 tqdm-4.64.1 uncertainties-3.1.7 webencodings-0.5.1
# Requirement already satisfied: matplotlib in /home/codespace/.local/lib/python3.10/site-packages (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: numpy>=1.19 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (1.23.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (4.37.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: astropy in /usr/local/python/3.10.7/lib/python3.10/site-packages (5.1)
# Requirement already satisfied: packaging>=19.0 in /home/codespace/.local/lib/python3.10/site-packages (from astropy) (21.3)
# Requirement already satisfied: pyerfa>=2.0 in /usr/local/python/3.10.7/lib/python3.10/site-packages (from astropy) (2.0.0.1)
# Requirement already satisfied: numpy>=1.18 in /home/codespace/.local/lib/python3.10/site-packages (from astropy) (1.23.3)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/python/3.10.7/lib/python3.10/site-packages (from astropy) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/codespace/.local/lib/python3.10/site-packages (from packaging>=19.0->astropy) (3.0.9)

# %% [markdown]
# ## Star Selection

# %%
TIC = 'TIC 284475976' # TIC Star ID
sector_data = lk.search_lightcurve(TIC, author = 'SPOC', sector = 23) # can remove each arg if needed
sector_data
# Out:
# SearchResult containing 1 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 23 2020   SPOC     120   284475976      0.0

# %%
lc = sector_data.download_all()
lc.plot()
# Out:
# <div id='66c70121-045f-4e87-9acd-44018fb05ccb'></div>
# <AxesSubplot: xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
lc = sector_data.download_all()
lc.plot()
sector_data = lk.search_lightcurve(TIC, author = 'SPOC', sector=23)
sector_data
lc = sector_data.download_all()
lc.plot(linewidth = 0, marker = '.')
lc.plot(linewidth = 0, marker = '.', color = 'lightcyan', alpha = 0.3)
# Out:
# <div id='b5583d85-7115-4444-b59e-a78b906aee1e'></div>
# <div id='77f2ca71-5cf5-4adb-b4ac-b1ff3fbdc6a3'></div>
# <div id='6d9ef8d0-5986-480c-a3e5-5acded7f419a'></div>
# <AxesSubplot: xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %% [markdown]
# ## Plotting from multiple sectors

# %%
TIC_2 = 'TIC 55525572'
available_data_all = lk.search_lightcurve(TIC_2, author = 'SPOC')
available_data_all
# Out:
# SearchResult containing 24 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 04 2018   SPOC     120    55525572      0.0
#   1 TESS Sector 05 2018   SPOC     120    55525572      0.0
#   2 TESS Sector 06 2018   SPOC     120    55525572      0.0
#   3 TESS Sector 08 2019   SPOC     120    55525572      0.0
#   4 TESS Sector 09 2019   SPOC     120    55525572      0.0
#   5 TESS Sector 10 2019   SPOC     120    55525572      0.0
#   6 TESS Sector 11 2019   SPOC     120    55525572      0.0
#   7 TESS Sector 12 2019   SPOC     120    55525572      0.0
#   8 TESS Sector 13 2019   SPOC     120    55525572      0.0
#   9 TESS Sector 27 2020   SPOC      20    55525572      0.0
# ...            ...  ...    ...     ...         ...      ...
#  14 TESS Sector 30 2020   SPOC     120    55525572      0.0
#  15 TESS Sector 31 2020   SPOC     120    55525572      0.0
#  16 TESS Sector 32 2020   SPOC     120    55525572      0.0
#  17 TESS Sector 33 2020   SPOC     120    55525572      0.0
#  18 TESS Sector 34 2021   SPOC     120    55525572      0.0
#  19 TESS Sector 35 2021   SPOC     120    55525572      0.0
#  20 TESS Sector 36 2021   SPOC     120    55525572      0.0
#  21 TESS Sector 37 2021   SPOC     120    55525572      0.0
#  22 TESS Sector 38 2021   SPOC     120    55525572      0.0
#  23 TESS Sector 39 2021   SPOC     120    55525572      0.0
# Length = 24 rows

# %%
select_sector = available_data_all[0:4]
select_sector
# Out:
# SearchResult containing 4 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 04 2018   SPOC     120    55525572      0.0
#   1 TESS Sector 05 2018   SPOC     120    55525572      0.0
#   2 TESS Sector 06 2018   SPOC     120    55525572      0.0
#   3 TESS Sector 08 2019   SPOC     120    55525572      0.0

# %%
lc_collection = select_sector.download_all() # download all the sectors ([0:4])
lc_collection
# Out:
# LightCurveCollection of 4 objects:
#     0: <TessLightCurve LABEL="TIC 55525572" SECTOR=4 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     1: <TessLightCurve LABEL="TIC 55525572" SECTOR=5 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     2: <TessLightCurve LABEL="TIC 55525572" SECTOR=6 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     3: <TessLightCurve LABEL="TIC 55525572" SECTOR=8 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>

# %%
lc_collection.plot(linewidth = 0, marker = '.')
# Out:
# <div id='712845eb-7457-4b69-9697-86f3d1cfc732'></div>
# <AxesSubplot: xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %% [markdown]
# ### Normalise graph points

# %%
lc_collection_stitched = lc_collection.stitch()
lc_collection_stitched.plot(linewidth = 0, marker = '.', color = 'red')
lc.normalize().plot()
# Out:
# <div id='a4dfca80-2c2d-4c9e-a53d-a67677e5d026'></div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [9], line 3
#       1 lc_collection_stitched = lc_collection.stitch()
#       2 lc_collection_stitched.plot(linewidth = 0, marker = '.', color = 'red')
# ----> 3 lc.normalize().plot()
#
# AttributeError: 'LightCurveCollection' object has no attribute 'normalize'

# %% [markdown]
# ## Binning Data

# %%
bin_time = 15/24/60 # LK uses day units, this is 15 minutes over 24 hours
lc_collection_binned = lc_collection.bin(bin_time)
lc_collection_binned.plot()

# %% [markdown]
# ### Plotting Region

# %% [markdown]
# fig, ax = plt.subplots(figsize = (10, 5))
# lc_collection.plot(ax = ax, linewidth = 0, marker = 'o', color = 'gold', markerSize = 1)
# lc_collection_binned.plot(ax = ax, linewidth = 0, marker = 'o', color = 'black', markerSize = 1)

# %% [markdown]
# ## Phase Folding

# %%
available_data_select = lk.search_lightcurve(TIC, author = 'SPOC')[0:9] # Query data, select data from mutliple sectors (e.g. all availablke first year TESS data)
lc_collection = available_data_select.download_all().stitch()
fig, ax = plt.subplots(figsize = (8,4))
lc_collection.plot(ax = ax, linewidth = 0, marker = 'o', color = 'purple', markersize = 1, alpha = 0.7)

# %%
period = 83.8979
t0 = 2125.847

lc_phased = lc_collection.fold(period = period, epoch_time = t0)
lc_phased.plot(linewidth = 0, color = 'gold', marker = '.', markersize = 1, alpha = 0.7)

lc_phased_binned = lc_phased.bin(15/24/60)
fig, ax = plt.subplots(figsize = (8,5)) # defines a plotting region to plot multiple data sets
lc_phased.plot(ax = ax, marker = '.', linewidth = 0, color = 'blue', alpha = 0.4, markersize = 3, label = 'unbinned')
lc_phased_binned.plot(ax = ax, marker = 'o', linewidth = 0, color = 'purple', alpha = 0.8, markersize = 6, label = 'binned')

plt.xlim(-2, 2) # upper and lower limit for x-axis, zooming in from -40, 40 wide to -2, 2 wide
plt.ylim(0.996, 1.004)
