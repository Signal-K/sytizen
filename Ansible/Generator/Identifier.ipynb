# %%
import sys
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install lightkurve
# !{sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install astropy
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install sklearn
# !{sys.executable} -m pip install xgboost
# !{sys.executable} -m pip install lightgbm # https://www.reddit.com/r/git/comments/sme7k4/add_specific_folder_with_submodule_to_a_repository/
# !{sys.executable} -m pip install catboost

import numpy as np
import pandas as pd
pd.set_option('display.max_colwidth', None)

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

import warnings
warnings.filterwarnings(action='ignore')
# Out:
# Requirement already satisfied: numpy in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (1.23.3)
# Requirement already satisfied: lightkurve in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (2.3.0)
# Requirement already satisfied: oktopus>=0.1.2 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from lightkurve) (0.1.2)
# Requirement already satisfied: matplotlib>=3.1 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from lightkurve) (3.6.1)
# Requirement already satisfied: bokeh>=1.1 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from lightkurve) (2.4.3)
# Requirement already satisfied: tqdm>=4.25.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from lightkurve) (4.64.1)
# Requirement already satisfied: astroquery>=0.3.10 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from lightkurve) (0.4.6)
# Requirement already satisfied: fbpca>=1.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from lightkurve) (1.0)
# Requirement already satisfied: patsy>=0.5.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from lightkurve) (0.5.3)
# Requirement already satisfied: urllib3>=1.23 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from lightkurve) (1.26.12)
# Requirement already satisfied: numpy>=1.18 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from lightkurve) (1.23.3)
# Requirement already satisfied: uncertainties>=3.1.4 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from lightkurve) (3.1.7)
# Requirement already satisfied: memoization>=0.3.1 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from lightkurve) (0.4.0)
# Requirement already satisfied: requests>=2.22.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from lightkurve) (2.28.1)
# Requirement already satisfied: pandas>=1.1.4 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from lightkurve) (1.5.0)
# Requirement already satisfied: astropy>=5.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from lightkurve) (5.1)
# Requirement already satisfied: beautifulsoup4>=4.6.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from lightkurve) (4.11.1)
# Requirement already satisfied: scikit-learn>=0.24.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from lightkurve) (1.1.2)
# Requirement already satisfied: scipy>=1.7 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from lightkurve) (1.9.2)
# Requirement already satisfied: pyerfa>=2.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from astropy>=5.0->lightkurve) (2.0.0.1)
# Requirement already satisfied: packaging>=19.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from astropy>=5.0->lightkurve) (21.3)
# Requirement already satisfied: PyYAML>=3.13 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from astropy>=5.0->lightkurve) (6.0)
# Requirement already satisfied: keyring>=4.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from astroquery>=0.3.10->lightkurve) (23.9.3)
# Requirement already satisfied: html5lib>=0.999 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from astroquery>=0.3.10->lightkurve) (1.1)
# Requirement already satisfied: pyvo>=1.1 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from astroquery>=0.3.10->lightkurve) (1.4)
# Requirement already satisfied: soupsieve>1.2 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from beautifulsoup4>=4.6.0->lightkurve) (2.3.2.post1)
# Requirement already satisfied: pillow>=7.1.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from bokeh>=1.1->lightkurve) (9.2.0)
# Requirement already satisfied: Jinja2>=2.9 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from bokeh>=1.1->lightkurve) (3.1.2)
# Requirement already satisfied: tornado>=5.1 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from bokeh>=1.1->lightkurve) (6.2)
# Requirement already satisfied: typing-extensions>=3.10.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from bokeh>=1.1->lightkurve) (4.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from matplotlib>=3.1->lightkurve) (4.37.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from matplotlib>=3.1->lightkurve) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from matplotlib>=3.1->lightkurve) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from matplotlib>=3.1->lightkurve) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from matplotlib>=3.1->lightkurve) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from matplotlib>=3.1->lightkurve) (2.8.2)
# Requirement already satisfied: autograd in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from oktopus>=0.1.2->lightkurve) (1.5)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from pandas>=1.1.4->lightkurve) (2022.4)
# Requirement already satisfied: six in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from patsy>=0.5.0->lightkurve) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from requests>=2.22.0->lightkurve) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from requests>=2.22.0->lightkurve) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from requests>=2.22.0->lightkurve) (3.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from scikit-learn>=0.24.0->lightkurve) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from scikit-learn>=0.24.0->lightkurve) (1.2.0)
# Requirement already satisfied: future in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from uncertainties>=3.1.4->lightkurve) (0.18.2)
# Requirement already satisfied: webencodings in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from html5lib>=0.999->astroquery>=0.3.10->lightkurve) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from Jinja2>=2.9->bokeh>=1.1->lightkurve) (2.1.1)
# Requirement already satisfied: SecretStorage>=3.2 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from keyring>=4.0->astroquery>=0.3.10->lightkurve) (3.3.3)
# Requirement already satisfied: jaraco.classes in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from keyring>=4.0->astroquery>=0.3.10->lightkurve) (3.2.3)
# Requirement already satisfied: jeepney>=0.4.2 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from keyring>=4.0->astroquery>=0.3.10->lightkurve) (0.8.0)
# Requirement already satisfied: cryptography>=2.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from SecretStorage>=3.2->keyring>=4.0->astroquery>=0.3.10->lightkurve) (38.0.1)
# Requirement already satisfied: more-itertools in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from jaraco.classes->keyring>=4.0->astroquery>=0.3.10->lightkurve) (8.14.0)
# Requirement already satisfied: cffi>=1.12 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring>=4.0->astroquery>=0.3.10->lightkurve) (1.15.1)
# Requirement already satisfied: pycparser in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring>=4.0->astroquery>=0.3.10->lightkurve) (2.21)
# Requirement already satisfied: matplotlib in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (3.6.1)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from matplotlib) (4.37.4)
# Requirement already satisfied: numpy>=1.19 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from matplotlib) (1.23.3)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: astropy in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (5.1)
# Requirement already satisfied: pyerfa>=2.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from astropy) (2.0.0.1)
# Requirement already satisfied: PyYAML>=3.13 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from astropy) (6.0)
# Requirement already satisfied: packaging>=19.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from astropy) (21.3)
# Requirement already satisfied: numpy>=1.18 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from astropy) (1.23.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from packaging>=19.0->astropy) (3.0.9)
# Requirement already satisfied: pandas in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.21.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from pandas) (1.23.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from pandas) (2022.4)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Collecting sklearn
#   Using cached sklearn-0.0-py2.py3-none-any.whl
# Requirement already satisfied: scikit-learn in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from sklearn) (1.1.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from scikit-learn->sklearn) (1.9.2)
# Requirement already satisfied: joblib>=1.0.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from scikit-learn->sklearn) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from scikit-learn->sklearn) (1.23.3)
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0
# Collecting xgboost
#   Downloading xgboost-1.6.2-py3-none-manylinux2014_x86_64.whl (255.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.9/255.9 MB 7.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: scipy in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from xgboost) (1.9.2)
# Requirement already satisfied: numpy in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from xgboost) (1.23.3)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.6.2
# Collecting lightgbm
#   Downloading lightgbm-3.3.3-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 39.2 MB/s eta 0:00:00:00:01
# Requirement already satisfied: scipy in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from lightgbm) (1.9.2)
# Requirement already satisfied: numpy in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from lightgbm) (1.23.3)
# Requirement already satisfied: wheel in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from lightgbm) (0.37.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from lightgbm) (1.1.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from scikit-learn!=0.22.0->lightgbm) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from scikit-learn!=0.22.0->lightgbm) (1.2.0)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-3.3.3
# Collecting catboost
#   Downloading catboost-1.1-cp310-none-manylinux1_x86_64.whl (76.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 MB 8.5 MB/s eta 0:00:00:00:0100:01
# Collecting graphviz
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from catboost) (1.9.2)
# Requirement already satisfied: matplotlib in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from catboost) (3.6.1)
# Requirement already satisfied: numpy>=1.16.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from catboost) (1.23.3)
# Requirement already satisfied: six in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from catboost) (1.16.0)
# Collecting plotly
#   Downloading plotly-5.10.0-py2.py3-none-any.whl (15.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 53.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pandas>=0.24.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from catboost) (1.5.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from pandas>=0.24.0->catboost) (2022.4)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from matplotlib->catboost) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from matplotlib->catboost) (9.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from matplotlib->catboost) (1.0.5)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from matplotlib->catboost) (4.37.4)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/codespace/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages (from matplotlib->catboost) (1.4.4)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.1.0-py3-none-any.whl (23 kB)
# Installing collected packages: tenacity, graphviz, plotly, catboost
# Successfully installed catboost-1.1 graphviz-0.20.1 plotly-5.10.0 tenacity-8.1.0

# %%
data = pd.read_csv('../Ansible/Data/cumulative.csv')
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 data = pd.read_csv('../Ansible/Data/cumulative.csv')
#       2 data
#
# File ~/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1729, in TextFileReader._make_engine(self, f, engine)
#    1727     is_text = False
#    1728     mode = "rb"
# -> 1729 self.handles = get_handle(
#    1730     f,
#    1731     mode,
#    1732     encoding=self.options.get("encoding", None),
#    1733     compression=self.options.get("compression", None),
#    1734     memory_map=self.options.get("memory_map", False),
#    1735     is_text=is_text,
#    1736     errors=self.options.get("encoding_errors", "strict"),
#    1737     storage_options=self.options.get("storage_options", None),
#    1738 )
#    1739 assert self.handles is not None
#    1740 f = self.handles.handle
#
# File ~/.local/share/virtualenvs/Ansible-7_0ZpX8W/lib/python3.10/site-packages/pandas/io/common.py:857, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     852 elif isinstance(handle, str):
#     853     # Check whether the filename is to be opened in binary mode.
#     854     # Binary mode does not support 'encoding' and 'newline'.
#     855     if ioargs.encoding and "b" not in ioargs.mode:
#     856         # Encoding
# --> 857         handle = open(
#     858             handle,
#     859             ioargs.mode,
#     860             encoding=ioargs.encoding,
#     861             errors=errors,
#     862             newline="",
#     863         )
#     864     else:
#     865         # Binary mode
#     866         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Ansible/Data/cumulative.csv'

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 50 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              9564 non-null   int64
#  1   kepid              9564 non-null   int64
#  2   kepoi_name         9564 non-null   object
#  3   kepler_name        2294 non-null   object
#  4   koi_disposition    9564 non-null   object
#  5   koi_pdisposition   9564 non-null   object
#  6   koi_score          8054 non-null   float64
#  7   koi_fpflag_nt      9564 non-null   int64
#  8   koi_fpflag_ss      9564 non-null   int64
#  9   koi_fpflag_co      9564 non-null   int64
#  10  koi_fpflag_ec      9564 non-null   int64
#  11  koi_period         9564 non-null   float64
#  12  koi_period_err1    9110 non-null   float64
#  13  koi_period_err2    9110 non-null   float64
#  14  koi_time0bk        9564 non-null   float64
#  15  koi_time0bk_err1   9110 non-null   float64
#  16  koi_time0bk_err2   9110 non-null   float64
#  17  koi_impact         9201 non-null   float64
#  18  koi_impact_err1    9110 non-null   float64
#  19  koi_impact_err2    9110 non-null   float64
#  20  koi_duration       9564 non-null   float64
#  21  koi_duration_err1  9110 non-null   float64
#  22  koi_duration_err2  9110 non-null   float64
#  23  koi_depth          9201 non-null   float64
#  24  koi_depth_err1     9110 non-null   float64
#  25  koi_depth_err2     9110 non-null   float64
#  26  koi_prad           9201 non-null   float64
#  27  koi_prad_err1      9201 non-null   float64
#  28  koi_prad_err2      9201 non-null   float64
#  29  koi_teq            9201 non-null   float64
#  30  koi_teq_err1       0 non-null      float64
#  31  koi_teq_err2       0 non-null      float64
#  32  koi_insol          9243 non-null   float64
#  33  koi_insol_err1     9243 non-null   float64
#  34  koi_insol_err2     9243 non-null   float64
#  35  koi_model_snr      9201 non-null   float64
#  36  koi_tce_plnt_num   9218 non-null   float64
#  37  koi_tce_delivname  9218 non-null   object
#  38  koi_steff          9201 non-null   float64
#  39  koi_steff_err1     9096 non-null   float64
#  40  koi_steff_err2     9081 non-null   float64
#  41  koi_slogg          9201 non-null   float64
#  42  koi_slogg_err1     9096 non-null   float64
#  43  koi_slogg_err2     9096 non-null   float64
#  44  koi_srad           9201 non-null   float64
#  45  koi_srad_err1      9096 non-null   float64
#  46  koi_srad_err2      9096 non-null   float64
#  47  ra                 9564 non-null   float64
#  48  dec                9564 non-null   float64
#  49  koi_kepmag         9563 non-null   float64
# dtypes: float64(39), int64(6), object(5)
# memory usage: 3.6+ MB

# %% [markdown]
# ## Preprocessing

# %%
def preprocess_inputs(df):
    df = df.copy()

    # Drop unused columns
    df = df.drop(['rowid', 'kepid', 'kepoi_name', 'kepler_name', 'koi_pdisposition', 'koi_score'], axis = 1)

    # Limit target values to CANDIDATE and CONFIRMED
    false_positive_rows = df.query("koi_disposition == 'FALSE POSITIVE'").index
    df = df.drop(false_positive_rows, axis = 0).reset_index(drop=True)

    # Drop columns with all missing values -> come back to these later (at some point)
    df = df.drop(['koi_teq_err1', 'koi_teq_err2'], axis = 1)

    # Fill remaining missing values
    df['koi_tce_delivname'] = df['koi_tce_delivname'].fillna(df['koi_tce_delivname'].mode()[0])
    for column in df.columns[df.isna().sum() > 0]:
        df[column] = df[column].fillna(df[column].mean())

    # One-hot encode koi_tce_delivname column
    delivname_dummies = pd.get_dummies(df['koi_tce_delivname'], prefix = 'delivname')
    df = pd.concat([df, delivname_dummies], axis = 1) # Add to dataset
    df = df.drop('koi_tce_delivname', axis = 1)

    # Split df into X and Y
    y = df['koi_disposition']
    X = df.drop('koi_disposition', axis = 1)

    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, shuffle = True, random_state = 1)

    # Scale the data | Same range of values /#/ https://www.youtube.com/watch?v=nklFC-_xi2U&t=663s
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = pd.DataFrame(scaler.transform(X_train), index = X_train.index, columns = X_train.columns)
    test = pd.DataFrame(scaler.transform(X_test), index = X_test.index, columns = X_test.columns)

    #return df
    return X_train, X_test, y_train, y_test

#X = preprocess_inputs(data)
#X

X_train, X_test, y_train, y_test = preprocess_inputs(data)
X_train
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 1673      -0.071134      -0.117116        -0.0355      -0.017742   -0.037165
# 1239      -0.071134      -0.117116        -0.0355      -0.017742   -0.004275
# 3589      -0.071134      -0.117116        -0.0355      -0.017742    0.174458
# 415       -0.071134      -0.117116        -0.0355      -0.017742   -0.037962
# 2925      -0.071134      -0.117116        -0.0355      -0.017742    0.010035
# ...             ...            ...            ...            ...         ...
# 2895      -0.071134      -0.117116        -0.0355      -0.017742   -0.035650
# 2763      -0.071134      -0.117116        -0.0355      -0.017742   -0.031798
# 905       -0.071134      -0.117116        -0.0355      -0.017742   -0.026434
# 3980      -0.071134      -0.117116        -0.0355      -0.017742   -0.034204
# 235       -0.071134      -0.117116        -0.0355      -0.017742   -0.037964
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 1673        -0.239706         0.239706    -0.497521         -0.000669
# 1239        -0.054711         0.054711     0.202478          0.092227
# 3589         1.954787        -1.954787    -0.239901          0.177133
# 415         -0.253911         0.253911     0.110849         -0.411112
# 2925         0.559955        -0.559955     0.873931          0.966253
# ...               ...              ...          ...               ...
# 2895        -0.206766         0.206766    -0.396396          0.736509
# 2763        -0.076652         0.076652    -0.276621         -0.121035
# 905         -0.229689         0.229689    -0.280512         -0.276861
# 3980        -0.235459         0.235459    -0.328916         -0.176973
# 235         -0.254281         0.254281    -0.488137         -0.430085
#
#       koi_time0bk_err2  ...  koi_slogg_err2  koi_srad  koi_srad_err1  \
# 1673          0.000669  ...        0.162643 -0.012212      -0.045685
# 1239         -0.092227  ...        0.548779 -0.083330      -0.292382
# 3589         -0.177133  ...       -2.636846  0.476722       3.648441
# 415           0.411112  ...       -0.947499 -0.096417       0.021787
# 2925         -0.966253  ...        0.210910  0.000876      -0.066771
# ...                ...  ...             ...       ...            ...
# 2895         -0.736509  ...       -1.092300 -0.080613       0.139864
# 2763          0.121035  ...       -1.019900 -0.081848       0.095585
# 905           0.276861  ...        0.259177 -0.031967      -0.146894
# 3980          0.176973  ...        0.247110 -0.121605      -0.324010
# 235           0.430085  ...        0.971115 -0.078638      -0.410459
#
#       koi_srad_err2        ra       dec  koi_kepmag  delivname_q1_q16_tce  \
# 1673       0.033953 -1.053449 -1.878703   -0.325469             -0.242131
# 1239       0.077194  0.659043  0.429700    0.597714             -0.242131
# 3589      -0.313997 -1.261863 -1.319194   -1.420679              4.129990
# 415        0.102868 -1.024723  0.715114    1.253905             -0.242131
# 2925       0.012333 -0.261806 -1.248770    0.522987             -0.242131
# ...             ...       ...       ...         ...                   ...
# 2895       0.090031  1.143456  1.093772    0.255217             -0.242131
# 2763       0.075842  0.628206 -1.259209    0.958113             -0.242131
# 905        0.025846  0.606496 -0.141000    0.904403             -0.242131
# 3980       0.144081 -1.268001  1.283264   -0.464025             -0.242131
# 235        0.122461 -0.373940  0.059139   -0.315350             -0.242131
#
#       delivname_q1_q17_dr24_tce  delivname_q1_q17_dr25_tce
# 1673                  -0.185756                   0.312051
# 1239                  -0.185756                   0.312051
# 3589                  -0.185756                  -3.204607
# 415                   -0.185756                   0.312051
# 2925                  -0.185756                   0.312051
# ...                         ...                        ...
# 2895                  -0.185756                   0.312051
# 2763                  -0.185756                   0.312051
# 905                   -0.185756                   0.312051
# 3980                  -0.185756                   0.312051
# 235                   -0.185756                   0.312051
#
# [3178 rows x 43 columns]

# %%
X.select_dtypes('object')
# Out:
#      koi_disposition
# 0          CONFIRMED
# 1          CONFIRMED
# 2          CONFIRMED
# 3          CONFIRMED
# 4          CONFIRMED
# ...              ...
# 4536       CANDIDATE
# 4537       CANDIDATE
# 4538       CANDIDATE
# 4539       CANDIDATE
# 4540       CANDIDATE
#
# [4541 rows x 1 columns]

# %% [markdown]
# # Training

# %%
models = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree": DecisionTreeClassifier(),
    "Neural Network": MLPClassifier(),
    "Random Forest": RandomForestClassifier(),
    "Gradient Boosting": GradientBoostingClassifier(),
}
