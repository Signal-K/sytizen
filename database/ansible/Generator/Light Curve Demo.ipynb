# %%
#!pip install lightkurve
#!pip install matplotlib

import matplotlib.pyplot as plt
import lightkurve as lk

# %%
# %matplotlib inline
TIC = 'kplr008120608'
sector_data = lk.search_lightcurve(TIC)#, author = 'Kepler', sector = 4)
sector_data
# Out:
# SearchResult containing 43 data products.
#
#  #       mission      year author exptime  target_name  distance
#                                      s                   arcsec
# --- ----------------- ---- ------ ------- ------------- --------
#   0 Kepler Quarter 01 2009 Kepler    1800 kplr008120608      0.0
#   1 Kepler Quarter 02 2009 Kepler    1800 kplr008120608      0.0
#   2 Kepler Quarter 03 2009 Kepler    1800 kplr008120608      0.0
#   3 Kepler Quarter 04 2010 Kepler    1800 kplr008120608      0.0
#   4 Kepler Quarter 05 2010 Kepler    1800 kplr008120608      0.0
#   5 Kepler Quarter 06 2010 Kepler    1800 kplr008120608      0.0
#   6 Kepler Quarter 07 2010 Kepler      60 kplr008120608      0.0
#   7 Kepler Quarter 07 2010 Kepler      60 kplr008120608      0.0
#   8 Kepler Quarter 07 2010 Kepler      60 kplr008120608      0.0
#   9 Kepler Quarter 07 2010 Kepler    1800 kplr008120608      0.0
# ...               ...  ...    ...     ...           ...      ...
#  33 Kepler Quarter 15 2012 Kepler      60 kplr008120608      0.0
#  34 Kepler Quarter 15 2013 Kepler      60 kplr008120608      0.0
#  35 Kepler Quarter 15 2013 Kepler    1800 kplr008120608      0.0
#  36 Kepler Quarter 16 2013 Kepler      60 kplr008120608      0.0
#  37 Kepler Quarter 16 2013 Kepler      60 kplr008120608      0.0
#  38 Kepler Quarter 16 2013 Kepler      60 kplr008120608      0.0
#  39 Kepler Quarter 16 2013 Kepler    1800 kplr008120608      0.0
#  40 Kepler Quarter 17 2013 Kepler      60 kplr008120608      0.0
#  41 Kepler Quarter 17 2013 Kepler      60 kplr008120608      0.0
#  42 Kepler Quarter 17 2013 Kepler    1800 kplr008120608      0.0
# Length = 43 rows

# %%
lc = sector_data.download()
lc.plot
# Out:
# /Users/buyer/Documents/Lens/client/api/.venv/lib/python3.10/site-packages/lightkurve/search.py:414: LightkurveWarning: Warning: 43 files available to download. Only the first file has been downloaded. Please use `download_all()` or specify additional criteria (e.g. quarter, campaign, or sector) to limit your search.
#   warnings.warn(
# <bound method LightCurve.plot of <KeplerLightCurve length=1626 LABEL="KIC 8120608" QUARTER=1 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#        time             flux      ...   pos_corr1      pos_corr2
#                     electron / s  ...      pix            pix
#        Time           float32     ...    float32        float32
# ------------------ -------------- ... -------------- --------------
# 131.51183908668463  2.0236930e+04 ...  1.3624026e-02 -2.5686027e-02
# 131.53227369402157  2.0228855e+04 ...  1.3650707e-02 -2.5533235e-02
# 131.55270820136502  2.0235031e+04 ...  1.3522197e-02 -2.5658274e-02
# 131.57314260864223  2.0237318e+04 ...  1.3296881e-02 -2.5862578e-02
# 131.59357711598568  2.0235371e+04 ...  1.3978796e-02 -2.5653420e-02
# 131.61401172321348  2.0234193e+04 ...  1.3850719e-02 -2.5588719e-02
# 131.63444613049796  2.0229381e+04 ...  1.3810308e-02 -2.5580501e-02
# 131.65488063777593  2.0236352e+04 ...  1.4040220e-02 -2.5366507e-02
# 131.67531524500373  2.0243742e+04 ...  1.3961208e-02 -2.5451215e-02
#                ...            ... ...            ...            ...
# 164.79955887427786  2.0193865e+04 ... -2.3912279e-02  3.6116417e-02
# 164.81999323354103  2.0197365e+04 ... -2.3845177e-02  3.6247857e-02
#  164.8404274925706  2.0199711e+04 ... -2.3515116e-02  3.5817385e-02
# 164.86086195136158  2.0198979e+04 ... -2.3695579e-02  3.5651486e-02
#  164.8812963101591  2.0190865e+04 ... -2.3829000e-02  3.5814047e-02
#   164.901730568723  2.0205182e+04 ... -2.4245968e-02  3.5684142e-02
# 164.92216492704756  2.0180527e+04 ... -2.4782157e-02  3.5903901e-02
# 164.94259938514733  2.0186822e+04 ... -2.4581298e-02  3.5626020e-02
# 164.96303364324558  2.0185568e+04 ... -2.4472406e-02  3.4950338e-02
# 164.98346800111176  2.0197186e+04 ... -2.4746416e-02  3.5053752e-02>

# %%
lc.plot(linewidth = 0, marker = '*', color = 'green', alpha = 1)
# Out:
# <Axes: xlabel='Time - 2454833 [BKJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
available_data_all = lk.search_lightcurve(TIC)
available_data_all
# Out:
# SearchResult containing 43 data products.
#
#  #       mission      year author exptime  target_name  distance
#                                      s                   arcsec
# --- ----------------- ---- ------ ------- ------------- --------
#   0 Kepler Quarter 01 2009 Kepler    1800 kplr008120608      0.0
#   1 Kepler Quarter 02 2009 Kepler    1800 kplr008120608      0.0
#   2 Kepler Quarter 03 2009 Kepler    1800 kplr008120608      0.0
#   3 Kepler Quarter 04 2010 Kepler    1800 kplr008120608      0.0
#   4 Kepler Quarter 05 2010 Kepler    1800 kplr008120608      0.0
#   5 Kepler Quarter 06 2010 Kepler    1800 kplr008120608      0.0
#   6 Kepler Quarter 07 2010 Kepler      60 kplr008120608      0.0
#   7 Kepler Quarter 07 2010 Kepler      60 kplr008120608      0.0
#   8 Kepler Quarter 07 2010 Kepler      60 kplr008120608      0.0
#   9 Kepler Quarter 07 2010 Kepler    1800 kplr008120608      0.0
# ...               ...  ...    ...     ...           ...      ...
#  33 Kepler Quarter 15 2012 Kepler      60 kplr008120608      0.0
#  34 Kepler Quarter 15 2013 Kepler      60 kplr008120608      0.0
#  35 Kepler Quarter 15 2013 Kepler    1800 kplr008120608      0.0
#  36 Kepler Quarter 16 2013 Kepler      60 kplr008120608      0.0
#  37 Kepler Quarter 16 2013 Kepler      60 kplr008120608      0.0
#  38 Kepler Quarter 16 2013 Kepler      60 kplr008120608      0.0
#  39 Kepler Quarter 16 2013 Kepler    1800 kplr008120608      0.0
#  40 Kepler Quarter 17 2013 Kepler      60 kplr008120608      0.0
#  41 Kepler Quarter 17 2013 Kepler      60 kplr008120608      0.0
#  42 Kepler Quarter 17 2013 Kepler    1800 kplr008120608      0.0
# Length = 43 rows

# %%
select_sector = available_data_all[0:4]
select_sector
# Out:
# SearchResult containing 4 data products.
#
#  #       mission      year author exptime  target_name  distance
#                                      s                   arcsec
# --- ----------------- ---- ------ ------- ------------- --------
#   0 Kepler Quarter 01 2009 Kepler    1800 kplr008120608      0.0
#   1 Kepler Quarter 02 2009 Kepler    1800 kplr008120608      0.0
#   2 Kepler Quarter 03 2009 Kepler    1800 kplr008120608      0.0
#   3 Kepler Quarter 04 2010 Kepler    1800 kplr008120608      0.0

# %%
lc_collection = select_sector.download_all()
lc_collection
# Out:
# LightCurveCollection of 4 objects:
#     0: <KeplerLightCurve LABEL="KIC 8120608" QUARTER=1 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#     1: <KeplerLightCurve LABEL="KIC 8120608" QUARTER=2 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#     2: <KeplerLightCurve LABEL="KIC 8120608" QUARTER=3 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#     3: <KeplerLightCurve LABEL="KIC 8120608" QUARTER=4 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>

# %%
lc_collection.plot(linewidth = 0, marker = '.') # KIC 10593626
# Out:
# <Axes: xlabel='Time - 2454833 [BKJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %% [markdown]
# ## Normalise Graph Points

# %%
lc_collection_stitched = lc_collection.stitch()
lc_collection_stitched.plot(linewidth = 0, marker = '.', color = 'red')
# Out:
# <Axes: xlabel='Time - 2454833 [BKJD days]', ylabel='Normalized Flux'>

# %%
lc.normalize().plot()
# Out:
# <Axes: xlabel='Time - 2454833 [BKJD days]', ylabel='Normalized Flux'>

# %% [markdown]
# ## Binning Data

# %%
bin_time = 15/24/60

#lc_collection_binned = lc_collection.bin(bin_time)

# %% [markdown]
# ## Plotting region

# %%
fig, ax = plt.subplots(figsize = (10, 5))
lc_collection.plot(ax = ax, linewidth = 0, marker = 'o', color = 'gold', markersize = 1)
#lc_collection_binned.plot(ax = ax, linewidth = 0, marker = 'o', color = 'black', markerSize = 1)
# Out:
# <Axes: xlabel='Time - 2454833 [BKJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %% [markdown]
# ## Phase Folding

# %%
available_data_select = lk.search_lightcurve(TIC, author = 'SPOC')[0:9] # Query data, select data from mutliple sectors (e.g. all availablke first year TESS data)
lc_collection = available_data_select.download_all().stitch()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[63], line 2
#       1 available_data_select = lk.search_lightcurve(TIC, author = 'SPOC')[0:9] # Query data, select data from mutliple sectors (e.g. all availablke first year TESS data)
# ----> 2 lc_collection = available_data_select.download_all().stitch()
#
# File ~/Documents/Lens/client/api/.venv/lib/python3.10/site-packages/lightkurve/utils.py:563, in suppress_stdout.<locals>.wrapper(*args, **kwargs)
#     561 sys.stdout = devnull
#     562 try:
# --> 563     return f(*args, **kwargs)
#     564 # restore to default
#     565 finally:
#     566     sys.stdout = old_out
#
# File ~/Documents/Lens/client/api/.venv/lib/python3.10/site-packages/lightkurve/search.py:494, in SearchResult.download_all(self, quality_bitmask, download_dir, cutout_size, **kwargs)
#     491 products = []
#     492 for idx in range(len(self.table)):
#     493     products.append(
# --> 494         self._download_one(
#     495             table=self.table[idx : idx + 1],
#     496             quality_bitmask=quality_bitmask,
#     497             download_dir=download_dir,
#     498             cutout_size=cutout_size,
#     499             **kwargs,
#     500         )
#     501     )
#     502 if isinstance(products[0], TargetPixelFile):
#     503     return TargetPixelFileCollection(products)
#
# File ~/Documents/Lens/client/api/.venv/lib/python3.10/site-packages/lightkurve/search.py:344, in SearchResult._download_one(self, table, quality_bitmask, download_dir, cutout_size, **kwargs)
#     342 download_url = table[:1]["dataURL"][0]
#     343 log.debug("Started downloading {}.".format(download_url))
# --> 344 download_response = Observations.download_products(
#     345     table[:1], mrp_only=False, download_dir=download_dir
#     346 )[0]
#     347 if download_response["Status"] != "COMPLETE":
#     348     raise LightkurveError(
#     349         f"Download of {download_url} failed. "
#     350         f"MAST returns {download_response['Status']}: {download_response['Message']}"
#     351         )
#
# File ~/Documents/Lens/client/api/.venv/lib/python3.10/site-packages/astroquery/mast/observations.py:734, in ObservationsClass.download_products(self, products, download_dir, cache, curl_flag, mrp_only, cloud_only, **filters)
#     732 else:
#     733     base_dir = download_dir.rstrip('/') + "/mastDownload"
# --> 734     manifest = self._download_files(products,
#     735                                     base_dir=base_dir,
#     736                                     cache=cache,
#     737                                     cloud_only=cloud_only)
#     739 return manifest
#
# File ~/Documents/Lens/client/api/.venv/lib/python3.10/site-packages/astroquery/mast/observations.py:617, in ObservationsClass._download_files(self, products, base_dir, cache, cloud_only)
#     614     local_path = os.path.join(local_path, os.path.basename(data_product['productFilename']))
#     616     # download the files
# --> 617     status, msg, url = self.download_file(data_product["dataURI"], local_path=local_path,
#     618                                           cache=cache, cloud_only=cloud_only)
#     620     manifest_array.append([local_path, status, msg, url])
#     622 manifest = Table(rows=manifest_array, names=('Local Path', 'Status', 'Message', "URL"))
#
# File ~/Documents/Lens/client/api/.venv/lib/python3.10/site-packages/astroquery/mast/observations.py:568, in ObservationsClass.download_file(self, uri, local_path, base_url, cache, cloud_only)
#     565             self._download_file(data_url, local_path,
#     566                                 cache=cache, head_safe=True, continuation=False)
#     567 else:
# --> 568     self._download_file(data_url, local_path,
#     569                         cache=cache, head_safe=True, continuation=False)
#     571 # check if file exists also this is where would perform md5,
#     572 # and also check the filesize if the database reliably reported file sizes
#     573 if (not os.path.isfile(local_path)) and (status != "SKIPPED"):
#
# File ~/Documents/Lens/client/api/.venv/lib/python3.10/site-packages/astroquery/query.py:351, in BaseQuery._download_file(self, url, local_filepath, timeout, auth, continuation, cache, method, head_safe, **kwargs)
#     331 """
#     332 Download a file.  Resembles `astropy.utils.data.download_file` but uses
#     333 the local ``_session``
#    (...)
#     347 head_safe : bool
#     348 """
#     350 if head_safe:
# --> 351     response = self._session.request("HEAD", url,
#     352                                      timeout=timeout, stream=True,
#     353                                      auth=auth, **kwargs)
#     354 else:
#     355     response = self._session.request(method, url,
#     356                                      timeout=timeout, stream=True,
#     357                                      auth=auth, **kwargs)
#
# File ~/Documents/Lens/client/api/.venv/lib/python3.10/site-packages/requests/sessions.py:542, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     537 send_kwargs = {
#     538     'timeout': timeout,
#     539     'allow_redirects': allow_redirects,
#     540 }
#     541 send_kwargs.update(settings)
# --> 542 resp = self.send(prep, **send_kwargs)
#     544 return resp
#
# File ~/Documents/Lens/client/api/.venv/lib/python3.10/site-packages/requests/sessions.py:655, in Session.send(self, request, **kwargs)
#     652 start = preferred_clock()
#     654 # Send the request
# --> 655 r = adapter.send(request, **kwargs)
#     657 # Total elapsed time of the request (approximately)
#     658 elapsed = preferred_clock() - start
#
# File ~/Documents/Lens/client/api/.venv/lib/python3.10/site-packages/requests/adapters.py:439, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     437 try:
#     438     if not chunked:
# --> 439         resp = conn.urlopen(
#     440             method=request.method,
#     441             url=url,
#     442             body=request.body,
#     443             headers=request.headers,
#     444             redirect=False,
#     445             assert_same_host=False,
#     446             preload_content=False,
#     447             decode_content=False,
#     448             retries=self.max_retries,
#     449             timeout=timeout
#     450         )
#     452     # Send the request.
#     453     else:
#     454         if hasattr(conn, 'proxy_pool'):
#
# File ~/Documents/Lens/client/api/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/Documents/Lens/client/api/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/Documents/Lens/client/api/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /opt/homebrew/Cellar/python@3.10/3.10.9/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File /opt/homebrew/Cellar/python@3.10/3.10.9/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /opt/homebrew/Cellar/python@3.10/3.10.9/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /opt/homebrew/Cellar/python@3.10/3.10.9/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.10/3.10.9/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.10/3.10.9/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots(figsize = (8,4))
lc_collection.plot(ax = ax, linewidth = 0, marker = 'o', color = 'purple', markersize = 1, alpha = 0.7)
# Out:
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %%
period = 83.8979
t0 = 2125.847

lc_phased = lc_collection.fold(period = period, epoch_time = t0)
lc_phased.plot(linewidth = 0, color = 'gold', marker = '.', markersize = 1, alpha = 0.7)

lc_phased_binned = lc_phased.bin(15/24/60)
fig, ax = plt.subplots(figsize = (8,5)) # defines a plotting region to plot multiple data sets
lc_phased.plot(ax = ax, marker = '.', linewidth = 0, color = 'blue', alpha = 0.4, markersize = 3, label = 'unbinned')
lc_phased_binned.plot(ax = ax, marker = 'o', linewidth = 0, color = 'purple', alpha = 0.8, markersize = 6, label = 'binned')

plt.axhline(0.9988)
plt.xlim(-2, 2) # upper and lower limit for x-axis, zooming in from -40, 40 wide to -2, 2 wide
plt.ylim(0.996, 1.004)
# Out:
# (0.996, 1.004)

# %% [markdown]
# ## Determining planet stats

# %%
# !pip install astropy
from astropy import units as u
import numpy as np
# Out:
# Requirement already satisfied: astropy in ./.venv/lib/python3.10/site-packages (5.2.2)
# Requirement already satisfied: PyYAML>=3.13 in ./.venv/lib/python3.10/site-packages (from astropy) (6.0)
# Requirement already satisfied: numpy>=1.20 in ./.venv/lib/python3.10/site-packages (from astropy) (1.24.2)
# Requirement already satisfied: packaging>=19.0 in ./.venv/lib/python3.10/site-packages (from astropy) (23.0)
# Requirement already satisfied: pyerfa>=2.0 in ./.venv/lib/python3.10/site-packages (from astropy) (2.0.0.3)
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b4c251b4-c11a-481e-8206-c29934eb75da' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
