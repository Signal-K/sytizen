# %%
# !pip install lightkurve
# %matplotlib inline
# Out:
# Requirement already satisfied: lightkurve in /opt/homebrew/lib/python3.10/site-packages (2.4.0)
# Requirement already satisfied: astropy>=5.0 in /opt/homebrew/lib/python3.10/site-packages (from lightkurve) (5.2.1)
# Requirement already satisfied: astroquery>=0.3.10 in /opt/homebrew/lib/python3.10/site-packages (from lightkurve) (0.4.6)
# Requirement already satisfied: beautifulsoup4>=4.6.0 in /opt/homebrew/lib/python3.10/site-packages (from lightkurve) (4.11.2)
# Requirement already satisfied: bokeh>=2.0.0 in /opt/homebrew/lib/python3.10/site-packages (from lightkurve) (3.0.3)
# Requirement already satisfied: fbpca>=1.0 in /opt/homebrew/lib/python3.10/site-packages (from lightkurve) (1.0)
# Requirement already satisfied: matplotlib>=3.1 in /opt/homebrew/lib/python3.10/site-packages (from lightkurve) (3.7.1)
# Requirement already satisfied: memoization>=0.3.1 in /opt/homebrew/lib/python3.10/site-packages (from lightkurve) (0.4.0)
# Requirement already satisfied: numpy>=1.18 in /opt/homebrew/lib/python3.10/site-packages (from lightkurve) (1.24.2)
# Requirement already satisfied: oktopus>=0.1.2 in /opt/homebrew/lib/python3.10/site-packages (from lightkurve) (0.1.2)
# Requirement already satisfied: pandas>=1.1.4 in /opt/homebrew/lib/python3.10/site-packages (from lightkurve) (1.5.3)
# Requirement already satisfied: patsy>=0.5.0 in /opt/homebrew/lib/python3.10/site-packages (from lightkurve) (0.5.3)
# Requirement already satisfied: requests>=2.22.0 in /opt/homebrew/lib/python3.10/site-packages (from lightkurve) (2.25.1)
# Requirement already satisfied: scikit-learn>=0.24.0 in /opt/homebrew/lib/python3.10/site-packages (from lightkurve) (1.2.2)
# Requirement already satisfied: scipy>=1.7 in /opt/homebrew/lib/python3.10/site-packages (from lightkurve) (1.10.1)
# Requirement already satisfied: tqdm>=4.25.0 in /opt/homebrew/lib/python3.10/site-packages (from lightkurve) (4.64.1)
# Requirement already satisfied: uncertainties>=3.1.4 in /opt/homebrew/lib/python3.10/site-packages (from lightkurve) (3.1.7)
# Requirement already satisfied: urllib3>=1.23 in /opt/homebrew/lib/python3.10/site-packages (from lightkurve) (1.26.12)
# Requirement already satisfied: pyerfa>=2.0 in /opt/homebrew/lib/python3.10/site-packages (from astropy>=5.0->lightkurve) (2.0.0.1)
# Requirement already satisfied: PyYAML>=3.13 in /opt/homebrew/lib/python3.10/site-packages (from astropy>=5.0->lightkurve) (5.4.1)
# Requirement already satisfied: packaging>=19.0 in /opt/homebrew/lib/python3.10/site-packages (from astropy>=5.0->lightkurve) (21.3)
# Requirement already satisfied: html5lib>=0.999 in /opt/homebrew/lib/python3.10/site-packages (from astroquery>=0.3.10->lightkurve) (1.1)
# Requirement already satisfied: keyring>=4.0 in /opt/homebrew/lib/python3.10/site-packages (from astroquery>=0.3.10->lightkurve) (23.13.1)
# Requirement already satisfied: pyvo>=1.1 in /opt/homebrew/lib/python3.10/site-packages (from astroquery>=0.3.10->lightkurve) (1.4.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/lib/python3.10/site-packages (from beautifulsoup4>=4.6.0->lightkurve) (2.4)
# Requirement already satisfied: Jinja2>=2.9 in /opt/homebrew/lib/python3.10/site-packages (from bokeh>=2.0.0->lightkurve) (3.1.2)
# Requirement already satisfied: contourpy>=1 in /opt/homebrew/lib/python3.10/site-packages (from bokeh>=2.0.0->lightkurve) (1.0.7)
# Requirement already satisfied: pillow>=7.1.0 in /opt/homebrew/lib/python3.10/site-packages (from bokeh>=2.0.0->lightkurve) (9.4.0)
# Requirement already satisfied: tornado>=5.1 in /opt/homebrew/lib/python3.10/site-packages (from bokeh>=2.0.0->lightkurve) (6.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /opt/homebrew/lib/python3.10/site-packages (from bokeh>=2.0.0->lightkurve) (2023.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib>=3.1->lightkurve) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib>=3.1->lightkurve) (4.39.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib>=3.1->lightkurve) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib>=3.1->lightkurve) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib>=3.1->lightkurve) (2.8.2)
# Requirement already satisfied: autograd in /opt/homebrew/lib/python3.10/site-packages (from oktopus>=0.1.2->lightkurve) (1.5)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.10/site-packages (from pandas>=1.1.4->lightkurve) (2022.7.1)
# Requirement already satisfied: six in /opt/homebrew/lib/python3.10/site-packages (from patsy>=0.5.0->lightkurve) (1.16.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/homebrew/lib/python3.10/site-packages (from requests>=2.22.0->lightkurve) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /opt/homebrew/lib/python3.10/site-packages (from requests>=2.22.0->lightkurve) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.10/site-packages (from requests>=2.22.0->lightkurve) (2022.9.24)
# Requirement already satisfied: joblib>=1.1.1 in /opt/homebrew/lib/python3.10/site-packages (from scikit-learn>=0.24.0->lightkurve) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/lib/python3.10/site-packages (from scikit-learn>=0.24.0->lightkurve) (3.1.0)
# Requirement already satisfied: future in /opt/homebrew/lib/python3.10/site-packages (from uncertainties>=3.1.4->lightkurve) (0.18.3)
# Requirement already satisfied: webencodings in /opt/homebrew/lib/python3.10/site-packages (from html5lib>=0.999->astroquery>=0.3.10->lightkurve) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.10/site-packages (from Jinja2>=2.9->bokeh>=2.0.0->lightkurve) (2.1.2)
# Requirement already satisfied: jaraco.classes in /opt/homebrew/lib/python3.10/site-packages (from keyring>=4.0->astroquery>=0.3.10->lightkurve) (3.2.3)
# Requirement already satisfied: importlib-metadata>=4.11.4 in /opt/homebrew/lib/python3.10/site-packages (from keyring>=4.0->astroquery>=0.3.10->lightkurve) (6.0.0)
# Requirement already satisfied: zipp>=0.5 in /opt/homebrew/lib/python3.10/site-packages (from importlib-metadata>=4.11.4->keyring>=4.0->astroquery>=0.3.10->lightkurve) (3.15.0)
# Requirement already satisfied: more-itertools in /opt/homebrew/lib/python3.10/site-packages (from jaraco.classes->keyring>=4.0->astroquery>=0.3.10->lightkurve) (9.1.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
import lightkurve as lk
import matplotlib.pyplot as plt
# Out:
# /opt/homebrew/lib/python3.10/site-packages/lightkurve/config/__init__.py:119: UserWarning: The default Lightkurve cache directory, used by download(), etc., has been moved to /Users/buyer/.lightkurve/cache. Please move all the files in the legacy directory /Users/buyer/.lightkurve-cache to the new location and remove the legacy directory. Refer to https://docs.lightkurve.org/reference/config.html#default-cache-directory-migration for more information.
#   warnings.warn(

# %% [markdown]
# ## Kepler-186

# %%
TIC = 'Kepler-186'
available_data_select = lk.search_lightcurve(TIC)[0:3]
lc_collection = available_data_select.download_all().stitch()
# %matplotlib inline
fig, ax = plt.subplots(figsize = (8, 4))
lc_collection.plot(ax = ax, linewidth = 0, marker = 0, color = 'green', markersize = 1, alpha = 0.8)
# Out:
# <Axes: xlabel='Time - 2454833 [BKJD days]', ylabel='Normalized Flux'>

# %%
# %matplotlib inline
bin_time = 15/24/60
lc_collection_binned = lc_collection.bin(bin_time)
lc_collection_binned.plot(color = 'gold', lw = 0, marker = '.')
# Out:
# <Axes: xlabel='Time - 2454833 [BKJD days]', ylabel='Normalized Flux'>

# %%
period = 10
t0 = 260

# %%
lc_phased = lc_collection.fold(period = period, epoch_time = t0)
# %matplotlib inline
fig, ax = plt.subplots(figsize = (8, 4))
lc_phased.plot(ax = ax, linewidth = 0, marker = 0, color = 'pink', markersize = 1, alpha = 0.8)
# Out:
# <Axes: xlabel='Phase [JD]', ylabel='Normalized Flux'>

# %% [markdown]
# Other planets:

# %% [markdown]
# Kepler-69c. G-Type star, inner of habitable zone (242 day orbit). Likely to be similar to Venus. 1.7x eRadii, 2.4 eMass
# Kepler-186f. 580LY from Earth. M-Type star.
# Kepler-442b. K-Type star, 1206LY from Earth. Not tidally locked.
# Kepler-22b. Obviously
# Trappist-1. M-Type
# TOI 700d. M-Type Star, 101.4LY from Earth. Likely to have retained a planetary atmosphere

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=50ad3984-69a9-496e-a121-efb59231e7e9' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
