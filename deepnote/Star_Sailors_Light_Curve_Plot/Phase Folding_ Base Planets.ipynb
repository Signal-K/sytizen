# %%
# !pip install lightkurve
# %matplotlib inline
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.9/265.9 kB 32.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 kB 51.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 11.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.4/98.4 kB 26.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 64.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 86.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 87.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 95.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 738.9/738.9 kB 77.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.5/739.5 kB 20.6 MB/s eta 0:00:00
# ...

# %%
import lightkurve as lk
import matplotlib.pyplot as plt

# %% [markdown]
# ## Kepler-186

# %%
TIC = 'Kepler-186'
available_data_select = lk.search_lightcurve(TIC)[0:3]
lc_collection = available_data_select.download_all().stitch()
# %matplotlib inline
fig, ax = plt.subplots(figsize = (8, 4))
lc_collection.plot(ax = ax, linewidth = 0, marker = 0, color = 'green', markersize = 1, alpha = 0.8)
# Out:
# <AxesSubplot: xlabel='Time - 2454833 [BKJD days]', ylabel='Normalized Flux'>

# %%
# %matplotlib inline
bin_time = 15/24/60
lc_collection_binned = lc_collection.bin(bin_time)
lc_collection_binned.plot(color = 'gold', lw = 0, marker = '.')
# Out:
# <AxesSubplot: xlabel='Time - 2454833 [BKJD days]', ylabel='Normalized Flux'>

# %%
period = 3.8
t0 = 260

# %%
lc_phased = lc_collection.fold(period = period, epoch_time = t0)
# %matplotlib inline
fig, ax = plt.subplots(figsize = (8, 4))
lc_phased.plot(ax = ax, linewidth = 0, marker = 0, color = 'pink', markersize = 1, alpha = 0.8)
# Out:
# <AxesSubplot: xlabel='Phase [JD]', ylabel='Normalized Flux'>

# %% [markdown]
# Other planets:

# %% [markdown]
# Kepler-69c. G-Type star, inner of habitable zone (242 day orbit). Likely to be similar to Venus. 1.7x eRadii, 2.4 eMass
# Kepler-186f. 580LY from Earth. M-Type star.
# Kepler-442b. K-Type star, 1206LY from Earth. Not tidally locked.
# Kepler-22b. Obviously
# Trappist-1. M-Type
# TOI 700d. M-Type Star, 101.4LY from Earth. Likely to have retained a planetary atmosphere

# %% [markdown]
# # Kepler-69

# %%
TIC = "TIC 275573429"
available_data_select = lk.search_lightcurve(TIC)[0:2]
lc_collection = available_data_select.download_all().stitch()
fig, ax = plt.subplots(figsize = (8,4))
lc_collection.plot(ax = ax, linewidth = 0, marker = 'o', color = 'purple', markersize = 1, alpha = 0.2)
# Out:
# <AxesSubplot: xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %%
# %matplotlib inline
bin_time = 15/24/60
lc_collection_binned = lc_collection.bin(bin_time)
lc_collection_binned.plot(color = 'gold', lw = 0, marker = '.')
# Out:
# <AxesSubplot: xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %%
period = 242
t0 = 1695

# %%
lc_phased = lc_collection.fold(period = period, epoch_time = t0)
# %matplotlib inline
fig, ax = plt.subplots(figsize = (8, 4))
lc_phased.plot(ax = ax, linewidth = 0, marker = 0, color = 'purple', markersize = 1)
# Out:
# <AxesSubplot: xlabel='Phase [JD]', ylabel='Normalized Flux'>

# %% [markdown]
# # Kepler-22

# %%
TIC = "TIC 275573429"
available_data_select = lk.search_lightcurve(TIC)[0:2]
lc_collection = available_data_select.download_all().stitch()
fig, ax = plt.subplots(figsize = (8,4))
lc_collection.plot(ax = ax, linewidth = 0, marker = 'o', color = 'purple', markersize = 1, alpha = 0.2)

# %%
# %matplotlib inline
bin_time = 15/24/60
lc_collection_binned = lc_collection.bin(bin_time)
lc_collection_binned.plot(color = 'gold', lw = 0, marker = '.')

# %%
period = 242
t0 = 1695

# %%
lc_phased = lc_collection.fold(period = period, epoch_time = t0)
# %matplotlib inline
fig, ax = plt.subplots(figsize = (8, 4))
lc_phased.plot(ax = ax, linewidth = 0, marker = 0, color = 'purple', markersize = 1)

# %% [markdown]
# # Kepler-442

# %%
TIC = "TIC 275573429"
available_data_select = lk.search_lightcurve(TIC)[0:2]
lc_collection = available_data_select.download_all().stitch()
fig, ax = plt.subplots(figsize = (8,4))
lc_collection.plot(ax = ax, linewidth = 0, marker = 'o', color = 'purple', markersize = 1, alpha = 0.2)

# %%
# %matplotlib inline
bin_time = 15/24/60
lc_collection_binned = lc_collection.bin(bin_time)
lc_collection_binned.plot(color = 'gold', lw = 0, marker = '.')

# %%
period = 242
t0 = 1695

# %%
lc_phased = lc_collection.fold(period = period, epoch_time = t0)
# %matplotlib inline
fig, ax = plt.subplots(figsize = (8, 4))
lc_phased.plot(ax = ax, linewidth = 0, marker = 0, color = 'purple', markersize = 1)

# %% [markdown]
# # Trappist-1

# %%
TIC = "TIC 278892590"
available_data_select = lk.search_lightcurve(TIC)[0:9]
lc_collection = available_data_select.download_all().stitch()
fig, ax = plt.subplots(figsize = (8,4))
lc_collection.plot(ax = ax, linewidth = 0, marker = 'o', color = 'purple', markersize = 1, alpha = 0.2)
# Out:
# <AxesSubplot: xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %%
# %matplotlib inline
bin_time = 15/24/60
lc_collection_binned = lc_collection.bin(bin_time)
lc_collection_binned.plot(color = 'gold', lw = 0, marker = '.')
# Out:
# <AxesSubplot: xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %%
period = 18
t0 = 3400

# %%
lc_phased = lc_collection.fold(period = period, epoch_time = t0)
# %matplotlib inline
fig, ax = plt.subplots(figsize = (8, 4))
lc_phased.plot(ax = ax, linewidth = 0, marker = 0, color = 'purple', markersize = 1)
# Out:
# <AxesSubplot: xlabel='Phase [JD]', ylabel='Normalized Flux'>

# %% [markdown]
# # TOI-700

# %%
TIC = "TIC 275573429"
available_data_select = lk.search_lightcurve(TIC)[0:2]
lc_collection = available_data_select.download_all().stitch()
fig, ax = plt.subplots(figsize = (8,4))
lc_collection.plot(ax = ax, linewidth = 0, marker = 'o', color = 'purple', markersize = 1, alpha = 0.2)
# Out:
# <AxesSubplot: xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %%
# %matplotlib inline
bin_time = 15/24/60
lc_collection_binned = lc_collection.bin(bin_time)
lc_collection_binned.plot(color = 'gold', lw = 0, marker = '.')
# Out:
# <AxesSubplot: xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %%
period = 242
t0 = 1695

# %%
lc_phased = lc_collection.fold(period = period, epoch_time = t0)
# %matplotlib inline
fig, ax = plt.subplots(figsize = (8, 4))
lc_phased.plot(ax = ax, linewidth = 0, marker = 0, color = 'purple', markersize = 1)
# Out:
# <AxesSubplot: xlabel='Phase [JD]', ylabel='Normalized Flux'>

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=50ad3984-69a9-496e-a121-efb59231e7e9' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
